# %% [markdown]
# # Maps Plots for Thesis

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import seaborn as sns
from pathlib import Path

data_path = Path.home()/'OneDrive'/'Kirstin'/'Uni'/'Year4'/'MSciProject'/'data_files'

# %% [markdown]
# ### AGAGE Map

# %% [markdown]
# This code makes a map plot with all of the active AGAGE atmospheric monitoring stations. It highlights the two utilised in the project - Mace Head and Gosan.

# %%
# Coordinates of the AGAGE monitoring stations (taken from https://agage.mit.edu/global-network)
# coordinates of sites explored
coordinates_explored = [(53.3267, -9.9046),  # MHD
                        (33.2924, 126.1616)] # GSN

labels_explored = ['MHD ', 'GSN ']
xytext_values = [(-29, -12.5), (20, -30)]

# coordinates of all sites
coordinates_sites = [
                     (144.6894, -40.6833),   # CGO
                     (-59.4321, 13.1651),    # RPB
                     (7.985883, 46.547767),  # JFJ
                     (10.7014, 44.1932),     # CMN
                     (-124.141, 41.0541),    # THD
                     (11.8867, 78.9072),      # ZEP
                     (-170.5644,-14.2474),  # SMO
                    ]

# creating world map
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()}, figsize=(15,15))
sns.set(style='whitegrid')
sns.set_palette("colorblind")

# plotting explored sites and adding labels
for i, ((lat, lon), label) in enumerate(zip(coordinates_explored, labels_explored)):
    ax.scatter(lon, lat, color='red', s=150, marker='x', zorder=2, edgecolor='black', linewidth=4)
    # ax.annotate(label, (lon, lat), color='black', fontsize=20, ha='center', va='bottom', zorder=3,
                # xytext=xytext_values[i], textcoords='offset points', weight='bold')
    
# plotting other sites
ax.scatter(*zip(*coordinates_sites), c='red', s=150, marker='x', zorder=2, label='Other Sites', edgecolor='black', linewidth=4)

ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, color='darkgreen', alpha=0.3)
ax.add_feature(cfeature.OCEAN, color='lightblue', alpha=0.7)
ax.set_global()
# ax.set_title('Map Showing the Locations of AGAGE Monitoring Stations', fontsize=15)


# add a north arrow
arrow_props = dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2)

ax.annotate('N', xy=(0.025, 0.18), xycoords='axes fraction', size=20, weight='bold',
            xytext=(0.025, 0.08), textcoords='axes fraction',
            arrowprops=arrow_props,
            horizontalalignment='center', verticalalignment='center')

# adding gridliens
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='black', alpha=0.4, linestyle='--', zorder=1)

plt.show()
# Out:
# c:\Users\kirst\OneDrive\Kirstin\Uni\Year4\MSciProject\my_code\optimising_algorithm\venv\Lib\site-packages\cartopy\mpl\geoaxes.py:1696: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   result = super().scatter(*args, **kwargs)
# c:\Users\kirst\OneDrive\Kirstin\Uni\Year4\MSciProject\my_code\optimising_algorithm\venv\Lib\site-packages\cartopy\mpl\geoaxes.py:1696: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   result = super().scatter(*args, **kwargs)
# c:\Users\kirst\OneDrive\Kirstin\Uni\Year4\MSciProject\my_code\optimising_algorithm\venv\Lib\site-packages\cartopy\mpl\geoaxes.py:1696: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   result = super().scatter(*args, **kwargs)

# %%
# Coordinates of the AGAGE monitoring stations (taken from https://agage.mit.edu/global-network)
# coordinates of sites explored
coordinates_explored = [(53.3267, -9.9046),     # MHD
                        (33.2924, 126.1616),    # GSN
                        (-40.6833, 144.6894),   # CGO
                        (13.1651, -59.4321),    # RPB
                        (46.547767, 7.985883),  # JFJ
                        (44.1932, 10.7014),     # CMN
                        (41.0541, -124.141),    # THD
                        (78.9072, 11.8867),     # ZEP
                        (-14.2474, -170.5644),  # SMO
]

labels_explored = ['MHD ', 'GSN ', 'CGO ', 'RPB ', 'JFJ ', 'CMN ', 'THD ', 'ZEP ', 'SMO ']
xytext_values = [(-29, -12.5), (20, -30), (-29, -12.5), (34, -12.5), (-29, -12.5), (20, -30), (-29, -12.5), (-25, -14), (35, -12.5)]


# creating world map
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()}, figsize=(15,15))
sns.set(style='whitegrid')
sns.set_palette("colorblind")

# plotting explored sites and adding labels
for i, ((lat, lon), label) in enumerate(zip(coordinates_explored, labels_explored)):
    ax.scatter(lon, lat, color='magenta', s=300, marker='^', zorder=2, edgecolor='black')
    ax.annotate(label, (lon, lat), color='black', fontsize=20, ha='center', va='bottom', zorder=3,
                xytext=xytext_values[i], textcoords='offset points', weight='bold')


ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, color='darkgreen', alpha=0.3)
ax.add_feature(cfeature.OCEAN, color='lightblue', alpha=0.7)
ax.set_global()
# ax.set_title('Map Showing the Locations of AGAGE Monitoring Stations', fontsize=15)


# add a north arrow
arrow_props = dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2)

ax.annotate('N', xy=(0.032, 0.26), xycoords='axes fraction', size=20, weight='bold',
            xytext=(0.032, 0.16), textcoords='axes fraction',
            arrowprops=arrow_props,
            horizontalalignment='center', verticalalignment='center')

# adding gridliens
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='black', alpha=0.4, linestyle='--', zorder=1)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Coordinates of the AGAGE monitoring stations
coordinates_explored = [
    (53.3267, -9.9046),     # MHD
    (33.2924, 126.1616),    # GSN
    (-40.6833, 144.6894),   # CGO
    (13.1651, -59.4321),    # RPB
    (46.547767, 7.985883),  # JFJ
    (44.1932, 10.7014),     # CMN
    (41.0541, -124.141),    # THD
    (78.9072, 11.8867),     # ZEP
    (-14.2474, -170.5644),  # SMO
]

labels_explored = ['Mace Head\n(Ireland)', 'Gosan\n(Korea)', 'Cape Grim\n(Tasmania)', 'Ragged Point\n(Barbados)', 
                   'Jungfraujoch\n(Switzerland)', 'Monte Cimone\n(Italy)', 'Trinidad Head\n(California)', 
                   'Ny-Ålesund\n(Svalbard)', 'Cape Matatula\n(American Samoa)']
xytext_values = [(-60, 0), (50, -25), (-50, 0), (60, 0), 
                 (-50, -25), (60, -25), (-60, 0), 
                 (-60, 0), (70, 0)]

# Creating world map
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()}, figsize=(15, 15))
sns.set(style='whitegrid')
sns.set_palette("colorblind")

# Plotting explored sites and adding labels
for i, ((lat, lon), label) in enumerate(zip(coordinates_explored, labels_explored)):
    ax.scatter(lon, lat, color='red', s=150, marker='^', zorder=2, linewidth=1, edgecolor='black')
    ax.annotate(label, xy=(lon, lat), xycoords='data', xytext=xytext_values[i], textcoords='offset points',
                bbox=dict(boxstyle="round,pad=0.3", edgecolor='black', facecolor='white', alpha=0.9),
                arrowprops=dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2.5),
                fontsize=10, color='black', weight='bold', ha='center', va='center')

ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, color='darkgreen', alpha=0.3)
ax.add_feature(cfeature.OCEAN, color='lightblue', alpha=0.7)
ax.set_global()

# Add a north arrow
arrow_props = dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2)
ax.annotate('N', xy=(0.032, 0.26), xycoords='axes fraction', size=20, weight='bold',
            xytext=(0.032, 0.16), textcoords='axes fraction',
            arrowprops=arrow_props,
            horizontalalignment='center', verticalalignment='center')

# Adding gridlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='black', alpha=0.4, linestyle='--', zorder=1)

plt.show()

# %%
# small map with similar formatting zooming in on mace head
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()}, figsize=(10, 10))
sns.set(style='whitegrid')
sns.set_palette("colorblind")

# Plotting explored sites and adding labels
ax.scatter(-9.9046, 53.3267, color='red', s=300, marker='^', zorder=2, linewidth=1, edgecolor='black')


ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, color='darkgreen', alpha=0.3)
ax.add_feature(cfeature.OCEAN, color='lightblue', alpha=0.7)
ax.set_extent([-15, 8, 45, 60])

# Add a north arrow
arrow_props = dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2)
ax.annotate('N', xy=(0.032, 0.15), xycoords='axes fraction', size=20, weight='bold',
            xytext=(0.032, 0.05), textcoords='axes fraction',
            arrowprops=arrow_props,
            horizontalalignment='center', verticalalignment='center')

# Adding gridlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='black', alpha=0.4, linestyle='--', zorder=1)

# %%
# same for Gosan, Korea
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()}, figsize=(10, 10))

# Plotting explored sites and adding labels
ax.scatter(126.1616, 33.2924, color='red', s=300, marker='^', zorder=2, linewidth=1, edgecolor='black')



ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, color='darkgreen', alpha=0.3)
ax.add_feature(cfeature.OCEAN, color='lightblue', alpha=0.7)
ax.set_extent([115, 140, 30, 45])

# Add a north arrow
arrow_props = dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2)
ax.annotate('N', xy=(0.032, 0.15), xycoords='axes fraction', size=20, weight='bold',
            xytext=(0.032, 0.05), textcoords='axes fraction',
            arrowprops=arrow_props,
            horizontalalignment='center', verticalalignment='center')

# Adding gridlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='black', alpha=0.4, linestyle='--', zorder=1)

plt.show()

# %%
# small map with similar formatting zooming in on Monte Cimone, Italy
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()}, figsize=(10, 10))
sns.set(style='whitegrid')
sns.set_palette("colorblind")

# Plotting explored sites and adding labels
ax.scatter(10.7014, 44.1932, color='red', s=300, marker='^', zorder=2, linewidth=1, edgecolor='black')

ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, color='darkgreen', alpha=0.3)
ax.add_feature(cfeature.OCEAN, color='lightblue', alpha=0.7)
ax.set_extent([5, 15, 40, 47])

# Add a north arrow
ax.annotate('N', xy=(0.032, 0.15), xycoords='axes fraction', size=20, weight='bold',
            xytext=(0.032, 0.05), textcoords='axes fraction',
            arrowprops=arrow_props,
            horizontalalignment='center', verticalalignment='center')

# Adding gridlines
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='black', alpha=0.4, linestyle='--', zorder=1)

plt.show()

# %% [markdown]
# ### DECC System Map

# %%
# coordinates of DECC stations
site_coords ={"TAC": [52.518, 1.139],
              "HFD": [50.973, 0.225],
              "RGL": [51.992, -2.537],
              "WAO": [52.950, 1.122]}

labels = ['Tacolneston\nNorfolk', 'Heathfield\nEast Sussex', 
          'Ridge Hill\nHerefordshire', 'Weybourne\nNorfolk']

xy_values = [(-50, -40), (25, -50), (-100, 25), (-25, 60)]

# creating map of UK
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()}, figsize=(15,15))
sns.set(style='whitegrid')
sns.set_palette("colorblind")

for i, (key, (lat, lon)) in enumerate(site_coords.items()):
    label = labels[i]
    ax.scatter(lon, lat, color='red', s=75, marker='x', zorder=2, linewidth=3)
    ax.annotate(label, xy=(lon, lat), xycoords='data', xytext=xy_values[i], textcoords='offset points',
                bbox=dict(boxstyle="round,pad=0.3", edgecolor='black', facecolor='white', alpha=0.9),
                arrowprops=dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2.5),
                fontsize=12, color='black', weight='bold', ha='center', va='center')
    
ax.coastlines()
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.LAND, color='darkgreen', alpha=0.3)
ax.add_feature(cfeature.OCEAN, color='lightblue', alpha=0.7)
ax.set_extent([-6, 2, 49, 54], crs=ccrs.PlateCarree())
ax.add_feature(cfeature.STATES, linestyle='--', edgecolor='black', linewidth=1, alpha=0.25)

# add a north arrow
arrow_props = dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2)
ax.annotate('N', xy=(0.032, 0.14), xycoords='axes fraction', size=20, weight='bold',
            xytext=(0.032, 0.04), textcoords='axes fraction',
            arrowprops=arrow_props,
            horizontalalignment='center', verticalalignment='center')

gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, linewidth=1, color='black', alpha=0.4, linestyle='--', zorder=1)

# %% [markdown]
# ### Grid System Map

# %% [markdown]
# This produces a map with the coordinates of the 17-point grid system created around Mace Head, Ireland.

# %%
# initialising data
# importing one year of ECMWF data that has been interpolated to 17-point grid system - 2015
ecmwf_2015 = xr.open_dataset(data_path/'meteorological_data'/'ECMWF'/'MHD'/'10m_wind_grid'/'10m_u_2015.nc').sel(time=slice("2015-01-01 00:00:00")).to_dataframe()

# creating coordinates for each point based on the point index of dataframe
lats = []
lons = []

for point in ecmwf_2015.index.get_level_values('points').unique():
    lat = ecmwf_2015.iloc[point].latitude
    lon = ecmwf_2015.iloc[point].longitude

    lats.append(lat)
    lons.append(lon)

most_east = max(lons)
most_west = min(lons)
most_north = max(lats)
most_south = min(lats)
# Out:
# c:\Users\kirst\OneDrive\Kirstin\Uni\Year4\MSciProject\my_code\optimising_algorithm\venv\Lib\site-packages\xarray\backends\plugins.py:80: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
# plotting grid points on map
fig, ax = plt.subplots(figsize=(8,15), subplot_kw={'projection':cartopy.crs.PlateCarree()})
img_extent = ((most_west-5), (most_east+20), (most_south-10), (most_north+5))
ax.set_extent(img_extent)

ax.coastlines(resolution='50m', color='black', linewidth=1, alpha=0.75)
ax.add_feature(cfeature.LAND, color='darkgreen', alpha=0.3)
ax.add_feature(cfeature.OCEAN, color='lightblue', alpha=0.7)

ax.scatter(lons[1:], lats[1:], transform=cartopy.crs.PlateCarree(), 
           s=200, color='black', marker='x', linewidth=3, zorder=10, edgecolor='black')

mhd_lat = ecmwf_2015.iloc[0].latitude
mhd_lon = ecmwf_2015.iloc[0].longitude

ax.scatter(mhd_lon, mhd_lat, s=400, color='red', marker='^', label="Mace Head", 
           alpha=1, zorder=12, edgecolor='black')

ax.legend(loc="upper right", fontsize=15)

# add a north arrow
arrow_props = dict(facecolor='black', arrowstyle='->', edgecolor='black', linewidth=2)

ax.annotate('N', xy=(0.90, 0.86), xycoords='axes fraction', size=20, weight='bold',
            xytext=(0.90, 0.76), textcoords='axes fraction',
            arrowprops=arrow_props,
            horizontalalignment='center', verticalalignment='center')


# add gridlines
gl = ax.gridlines(crs=cartopy.crs.PlateCarree(), draw_labels=True, linewidth=1, color='black', alpha=0.4, linestyle='--')

plt.show()
# Out:
# c:\Users\kirst\OneDrive\Kirstin\Uni\Year4\MSciProject\my_code\optimising_algorithm\venv\Lib\site-packages\cartopy\mpl\geoaxes.py:1696: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   result = super().scatter(*args, **kwargs)
